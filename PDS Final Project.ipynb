# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

# %%
begin_date = dt.date(2019, 10, 8)
end_date = dt.date(2019, 11, 8)

limit = 1000
lang = "english"

# %%
tweets = query_tweets("trump", 
                      begindate = begin_date,
                      enddate = end_date,
                      limit = limit,
                      lang = lang)
# Out:
# INFO: queries: ['trump since:2019-10-08 until:2019-10-09', 'trump since:2019-10-09 until:2019-10-11', 'trump since:2019-10-11 until:2019-10-12', 'trump since:2019-10-12 until:2019-10-14', 'trump since:2019-10-14 until:2019-10-15', 'trump since:2019-10-15 until:2019-10-17', 'trump since:2019-10-17 until:2019-10-18', 'trump since:2019-10-18 until:2019-10-20', 'trump since:2019-10-20 until:2019-10-21', 'trump since:2019-10-21 until:2019-10-23', 'trump since:2019-10-23 until:2019-10-25', 'trump since:2019-10-25 until:2019-10-26', 'trump since:2019-10-26 until:2019-10-28', 'trump since:2019-10-28 until:2019-10-29', 'trump since:2019-10-29 until:2019-10-31', 'trump since:2019-10-31 until:2019-11-01', 'trump since:2019-11-01 until:2019-11-03', 'trump since:2019-11-03 until:2019-11-04', 'trump since:2019-11-04 until:2019-11-06', 'trump since:2019-11-06 until:2019-11-08']
# INFO: Querying trump since:2019-10-08 until:2019-10-09
# INFO: Querying trump since:2019-10-11 until:2019-10-12
# INFO: Querying trump since:2019-10-09 until:2019-10-11
# INFO: Querying trump since:2019-10-12 until:2019-10-14
# INFO: Querying trump since:2019-10-15 until:2019-10-17
# INFO: Querying trump since:2019-10-17 until:2019-10-18
# INFO: Querying trump since:2019-10-14 until:2019-10-15
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-08%20until%3A2019-10-09&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-11%20until%3A2019-10-12&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-12%20until%3A2019-10-14&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-15%20until%3A2019-10-17&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-09%20until%3A2019-10-11&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-14%20until%3A2019-10-15&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-17%20until%3A2019-10-18&l=english
# INFO: Querying trump since:2019-10-18 until:2019-10-20
# INFO: Querying trump since:2019-10-20 until:2019-10-21
# INFO: Using proxy 5.58.85.32:59824
# INFO: Querying trump since:2019-10-21 until:2019-10-23
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Querying trump since:2019-10-25 until:2019-10-26
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-18%20until%3A2019-10-20&l=english
# INFO: Querying trump since:2019-10-26 until:2019-10-28
# INFO: Querying trump since:2019-10-23 until:2019-10-25
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-20%20until%3A2019-10-21&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Querying trump since:2019-10-28 until:2019-10-29
# INFO: Querying trump since:2019-10-29 until:2019-10-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-21%20until%3A2019-10-23&l=english
# INFO: Querying trump since:2019-11-03 until:2019-11-04
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Querying trump since:2019-10-31 until:2019-11-01
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-25%20until%3A2019-10-26&l=english
# INFO: Querying trump since:2019-11-01 until:2019-11-03
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-28%20until%3A2019-10-29&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Querying trump since:2019-11-06 until:2019-11-08
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-29%20until%3A2019-10-31&l=english
# INFO: Querying trump since:2019-11-04 until:2019-11-06
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-23%20until%3A2019-10-25&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-26%20until%3A2019-10-28&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-10-31%20until%3A2019-11-01&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-11-03%20until%3A2019-11-04&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-11-01%20until%3A2019-11-03&l=english
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-11-06%20until%3A2019-11-08&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=trump%20since%3A2019-11-04%20until%3A2019-11-06&l=english
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Using proxy 5.58.85.32:59824
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1192592559496843265-1192592567227109382&q=trump%20since%3A2019-11-06%20until%3A2019-11-08&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1183895252928610305-1183895258209411073&q=trump%20since%3A2019-10-14%20until%3A2019-10-15&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1184620028517371904-1184620033701486593&q=trump%20since%3A2019-10-15%20until%3A2019-10-17&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1182808088077713408-1182808094541144064&q=trump%20since%3A2019-10-11%20until%3A2019-10-12&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1185707189232721920-1185707197398806529&q=trump%20since%3A2019-10-18%20until%3A2019-10-20&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1184982417523826688-1184982422066089984&q=trump%20since%3A2019-10-17%20until%3A2019-10-18&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1190780621351718913-1190780627433467906&q=trump%20since%3A2019-11-01%20until%3A2019-11-03&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187881520544923649-1187881524865028096&q=trump%20since%3A2019-10-25%20until%3A2019-10-26&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1183532863272022016-1183532870457004032&q=trump%20since%3A2019-10-12%20until%3A2019-10-14&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1191143002707779584-1191143015605264384&q=trump%20since%3A2019-11-03%20until%3A2019-11-04&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1186794356092493826-1186794361243066369&q=trump%20since%3A2019-10-21%20until%3A2019-10-23&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188606295177334784-1188606300701151232&q=trump%20since%3A2019-10-26%20until%3A2019-10-28&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1182445704393809921-1182445706876985347&q=trump%20since%3A2019-10-09%20until%3A2019-10-11&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1181720925529677824-1181720930810241024&q=trump%20since%3A2019-10-08%20until%3A2019-10-09&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1190055846253867009-1190055851765223425&q=trump%20since%3A2019-10-31%20until%3A2019-11-01&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1189693456500903936-1189693464251969536&q=trump%20since%3A2019-10-29%20until%3A2019-10-31&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1191867783606394880-1191867790900072448&q=trump%20since%3A2019-11-04%20until%3A2019-11-06&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1186069577832321024-1186069585277177857&q=trump%20since%3A2019-10-20%20until%3A2019-10-21&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187519130863394816-1187519137133879297&q=trump%20since%3A2019-10-23%20until%3A2019-10-25&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188968682795474944-1188968687681835010&q=trump%20since%3A2019-10-28%20until%3A2019-10-29&l=english
# INFO: Using proxy 46.235.71.241:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKrpp6f4jCEWjMC-teGn-IwhEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-11-06%20until%3A2019-11-08&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKahuJ2F7iAWgoC7zd-dhe4gEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-14%20until%3A2019-10-15&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLqZ9-jO8CAWgoC16Z3pzvAgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-15%20until%3A2019-10-17&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKb1juyW6iAWgICnib_sluogEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-11%20until%3A2019-10-12&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLvZ387z8SAWgMCi7YHP8_EgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-17%20until%3A2019-10-18&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgL3d9rqo5iAWgIC1iZ67qOYgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-08%20until%3A2019-10-09&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKa14PyZ_CAWgMCizYD9mfwgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-25%20until%3A2019-10-26&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwL6lp_nRgiEWgMC9heH50YIhEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-29%20until%3A2019-10-31&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgL_dgZq99CAWgsCjyb6avfQgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-18%20until%3A2019-10-20&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLSdmMjj_iAWgMCqscHI4_4gEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-26%20until%3A2019-10-28&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLTR0KrAhiEWhMC1-f2qwIYhEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-11-01%20until%3A2019-11-03&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgKeFusur-CAWgoCjteDLq_ggEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-21%20until%3A2019-10-23&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLvR5tuuiiEWgIC12aDcroohEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-11-04%20until%3A2019-11-06&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLWtld_2gyEWgsC6tb7f9oMhEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-31%20until%3A2019-11-01&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKP1yrfg7CAWgMC0uYC44OwgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-12%20until%3A2019-10-14&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLeRgJDlhyEWgIC3neCQ5YchEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-11-03%20until%3A2019-11-04&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKOJzoby6CAWhoC1yeCG8uggEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-09%20until%3A2019-10-11&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLWx9q2IgCEWhMC05ZquiIAhEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-28%20until%3A2019-10-29&l=english
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgL_x8pb1-iAWgoC_zaGX9fogEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-23%20until%3A2019-10-25&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwL6Z5__h9SAWgsC61Z6A4vUgEjUAFQAlAFUAFQAA&q=trump%20since%3A2019-10-20%20until%3A2019-10-21&l=english
# INFO: Using proxy 103.85.220.18:46615
# INFO: Using proxy 103.85.220.18:46615
# INFO: Got 59 tweets for trump%20since%3A2019-11-06%20until%3A2019-11-08.
# INFO: Got 59 tweets (59 new).
# INFO: Got 56 tweets for trump%20since%3A2019-10-15%20until%3A2019-10-17.
# INFO: Got 115 tweets (56 new).
# INFO: Got 57 tweets for trump%20since%3A2019-10-14%20until%3A2019-10-15.
# INFO: Got 172 tweets (57 new).
# INFO: Got 57 tweets for trump%20since%3A2019-10-11%20until%3A2019-10-12.
# INFO: Got 229 tweets (57 new).
# INFO: Got 53 tweets for trump%20since%3A2019-10-17%20until%3A2019-10-18.
# INFO: Got 282 tweets (53 new).
# INFO: Got 60 tweets for trump%20since%3A2019-10-25%20until%3A2019-10-26.
# INFO: Got 57 tweets for trump%20since%3A2019-11-01%20until%3A2019-11-03.
# INFO: Got 342 tweets (60 new).
# INFO: Got 57 tweets for trump%20since%3A2019-11-04%20until%3A2019-11-06.
# INFO: Got 51 tweets for trump%20since%3A2019-10-29%20until%3A2019-10-31.
# INFO: Got 57 tweets for trump%20since%3A2019-10-08%20until%3A2019-10-09.
# INFO: Got 60 tweets for trump%20since%3A2019-10-31%20until%3A2019-11-01.
# INFO: Got 399 tweets (57 new).
# INFO: Got 456 tweets (57 new).
# INFO: Got 59 tweets for trump%20since%3A2019-10-20%20until%3A2019-10-21.
# INFO: Got 507 tweets (51 new).
# INFO: Got 58 tweets for trump%20since%3A2019-11-03%20until%3A2019-11-04.
# INFO: Got 564 tweets (57 new).
# INFO: Got 624 tweets (60 new).
# INFO: Got 683 tweets (59 new).
# INFO: Got 741 tweets (58 new).
# INFO: Got 60 tweets for trump%20since%3A2019-10-12%20until%3A2019-10-14.
# INFO: Got 801 tweets (60 new).
# INFO: Got 59 tweets for trump%20since%3A2019-10-28%20until%3A2019-10-29.
# INFO: Got 59 tweets for trump%20since%3A2019-10-18%20until%3A2019-10-20.
# INFO: Got 860 tweets (59 new).
# INFO: Got 919 tweets (59 new).
# INFO: Got 59 tweets for trump%20since%3A2019-10-09%20until%3A2019-10-11.
# INFO: Got 55 tweets for trump%20since%3A2019-10-23%20until%3A2019-10-25.
# INFO: Got 54 tweets for trump%20since%3A2019-10-21%20until%3A2019-10-23.
# INFO: Got 973 tweets (54 new).
# INFO: Got 1028 tweets (55 new).
# INFO: Got 1087 tweets (59 new).
# INFO: Got 55 tweets for trump%20since%3A2019-10-26%20until%3A2019-10-28.
# INFO: Got 1142 tweets (55 new).

# %%
df = pd.DataFrame(t.__dict__ for t in tweets)

# %%
set(df.screen_name)
# Out:
# {'12cocomero12',
#  '2ndBCD',
#  '3drummers',
#  '41MARGIE41',
#  '4b1ae65aaef04bd',
#  '53SkimmerB',
#  '619SDBOLTS',
#  'AJDarkstar',
#  'AJWoodson',
#  'APPROVEMAN',
#  'AR152A',
#  'ATWURNS',
#  'AllRiseAmerica',
#  'AllanGuerrina',
#  'AlsoGrateful',
#  'Alwaystruthseek',
#  'AmandaD85547309',
#  'Amyisverybusy',
#  'Anfini00',
#  'AngDonlon',
#  'Angelsfan4life',
#  'Anusuu',
#  'Areana50',
#  'Athena4Freedom',
#  'AudreyNashville',
#  'AukerDean',
#  'AymaanOfficial',
#  'BDWB3',
#  'BVaags',
#  'BamasLadyJ',
#  'Barbara38H',
#  'BarbaraOlavarr1',
#  'BarkinDavid',
#  'BassistOld',
#  'BeachDude_FB',
#  'BellaMax12',
#  'Benson_TheComic',
#  'BettyN1956',
#  'BillCzechowski',
#  'BillPalmer',
#  'BillyBradd',
#  'BingoThaGringo',
#  'Blackout20',
#  'BobbyBurke',
#  'BoiagoIngrid',
#  'Brian6125',
#  'BrianFi05298915',
#  'BronzCat2',
#  'Brooke89342147',
#  'BruceWatson43',
#  'Bryan_Baruch1',
#  'BrysonVapeShop',
#  'BumpItMcCarthy',
#  'BurgessOwens',
#  'CAGold3',
#  'CAWPBT',
#  'CAnative_BC',
#  'CAnderson2020',
#  'CLEbilly',
#  'CadetTaco',
#  'CalvinPvet',
#  'Canadians4RG',
#  'CapRogers2020',
#  'CarolineInTheCT',
#  'CaseyC89IPA',
#  'CatintheHome',
#  'Cato_Cat',
#  'ChampRed2YT',
#  'ChefRyanSpragg',
#  'CherylDamon4',
#  'Chileman55',
#  'Chris11962',
#  'Chris32534266',
#  'ChristineOrland',
#  'ChuckUmeboshi',
#  'Clearvi66035749',
#  'Coleman_wagoner',
#  'CommonSense013',
#  'Congoliza',
#  'Corybehm2',
#  'CplFoxCo2_2',
#  'CreateToRebel',
#  'CryptoEcuadorio',
#  'Cubie1944',
#  'CurranBrock',
#  'Cybrarian64',
#  'DChattari',
#  'DHDCPREMIER1',
#  'DJMaurice71',
#  'DJimmyJamm',
#  'Dacob6',
#  'DadoLedgeNnoni',
#  'DagmarUnger',
#  'Dalilover1904',
#  'DanielC29395655',
#  'Darth_Timber',
#  'Dave_in_Dayton',
#  'DavidGoo9',
#  'DavidMe42591088',
#  'Davo20890211',
#  'DebD26591439',
#  'DeborahSotti',
#  'Dedra33417791',
#  'DeirdreJones54',
#  'DennisRadcliff3',
#  'Deplorable36',
#  'DianAandDennis',
#  'DimitarBechev',
#  'Dist4Coalition',
#  'Divinity11',
#  'DonaldBConradI3',
#  'DonnaThorson',
#  'Doomz__Dayz',
#  'Doug_Profitt',
#  'Dukepatriot50',
#  'EMastrro',
#  'Eansanead',
#  'Electionparty46',
#  'Elle4Trump',
#  'EllenHanon',
#  'Ellis_Millshire',
#  'FARCRY1116',
#  'FLkVAVYrIdfqEAD',
#  'FalcoTracy',
#  'FeriaInvestor',
#  'FrankG1194',
#  'Fred87304702',
#  'FredoLorenz',
#  'FritzHayek',
#  'GBiczkow',
#  'GHelsius',
#  'GatsMomm',
#  'GeoMor6',
#  'GeoffTebbetts',
#  'GlickIi',
#  'GoP__Botched',
#  'Gracias42630110',
#  'Granval04',
#  'GretaMiddendor1',
#  'Grrr_ammy',
#  'HRCpersists',
#  'HafizDoc',
#  'HeibultEric',
#  'HeliJoc',
#  'HelloShunshine1',
#  'HettlingerKaren',
#  'Highlan78027671',
#  'Hippie_Grannie',
#  'HoffmanNate',
#  'Hokibil',
#  'Hugroms',
#  'HygeNana',
#  'IAmHopefulAgain',
#  'IAmNotOk_Ok',
#  'ILIASIYUN',
#  'IShallResist',
#  'IT_not_real',
#  'IamIamkidt',
#  'Ibro_7x',
#  'Ignatius4DJT',
#  'ImChaunce',
#  'ImpeachResist1',
#  'Ironfistmonk',
#  'JAGJRGAMING',
#  'JAlford1493',
#  'JHenry0716',
#  'JSaint2019',
#  'JTWeaver6',
#  'JackRIC60809912',
#  'Jacopo_della_Q',
#  'Jaime4ou',
#  'JaneBen26',
#  'JanetTxBlessed',
#  'Jarnocan',
#  'JasonQuinter',
#  'JayCory7',
#  'Jennife31060429',
#  'Jer05',
#  'Jess_deladono',
#  'JetgirlmaryM',
#  'JewishNewsViews',
#  'JoanRomberger',
#  'JoeGlassman3',
#  'JoeHoken',
#  'JoeSchm14314510',
#  'Jopatmc1967',
#  'JosephChez',
#  'Jusdoneitagain',
#  'KB03COBRA',
#  'KKatMiss',
#  'KallGov',
#  'Kathryn66307867',
#  'KathyCronin007',
#  'KatiePhang',
#  'KayeGertz',
#  'KeepOnTrumpin20',
#  'Keepcoo36182526',
#  'KeitaKay',
#  'KellenSeason',
#  'KenDoss6',
#  'KevinWi52059035',
#  'KidApologize',
#  'KimballBeck',
#  'KoreyDevine',
#  'KpSimpl',
#  'KrisInRVA',
#  'Krixkroxer',
#  'KrystleSomers',
#  'KyleJamesHoward',
#  'LB0nes',
#  'LBisaillon',
#  'LDesopo',
#  'LPeckerman',
#  'LarryBlaze6',
#  'LaurenPotterfi1',
#  'LeeBake30644561',
#  'LeeHowa25847497',
#  'Legends_Hollow',
#  'LeinsLens',
#  'LennyLLM',
#  'LeonardABurke6',
#  'LewisFilewis1',
#  'LiberalDeadHead',
#  'LindsaySue2',
#  'LionInTheGrass',
#  'LizFoxSays',
#  'Lorink9',
#  'LoveDomine',
#  'Luci9711',
#  'Luckydawg',
#  'Lucy72794184',
#  'MAGAKatydid',
#  'MGSnyder12172',
#  'MGill_USA',
#  'MKay54',
#  'MN_NICE_PERSON',
#  'MRCleve3',
#  'MRSTXFabFace',
#  'MaddiMatilda',
#  'Maglovelife4365',
#  'MaherMahert',
#  'ManeBlonde',
#  'Marce_garciacai',
#  'MarcelDiamante',
#  'MarilynCapps',
#  'MarkElderCO',
#  'Markfry809',
#  'Matt60944173',
#  'MattHartmann14',
#  'MaximumDr1ve',
#  'Mayes3D',
#  'Mememem87156920',
#  'Mennonitemare',
#  'Michael12501463',
#  'MichaelKoropsak',
#  'MichaelMiguelCE',
#  'MichaelPMulhall',
#  'MickeyD06347993',
#  'MikeCassamasse',
#  'MisterR3sist3R',
#  'MiyaFHaund',
#  'Moemc8',
#  'MonteAllen5',
#  'MoscowMcConnell',
#  'MoscowMitch2020',
#  'MrRichardPaul',
#  'MsLuciaR',
#  'MsStMichael',
#  'Muneerakhair',
#  'MvvnusF',
#  'Mysstyblue',
#  'Mystara99',
#  'MzPhiOne',
#  'NYCgirl_InFL',
#  'NathanScogin',
#  'Norm16967317',
#  'NotMyFlyMonkeys',
#  'NyerinFl',
#  'OB4EKvaba647LR5',
#  'Oaguabonita',
#  'OlafSummer2020',
#  'OldStudentnow',
#  'OneGlobalTribe',
#  'OnyxMant',
#  'OpiesDaughter',
#  'P4boxers',
#  'PBCruzer',
#  'PCFitz1776',
#  'PEYESTRO',
#  'PEltzholtz',
#  'PKekbar',
#  'POTUSisALiar',
#  'PWSuver',
#  'Pal3Z',
#  'PamelaW31986513',
#  'PatchesLeblanc',
#  'Patriotress',
#  'PatsLadi99',
#  'Paul42980402',
#  'PaulELarsen',
#  'Pecker_Grabber',
#  'Perpetual_Now',
#  'Phyllis_Sudds',
#  'Playday89679442',
#  'PoemByTheSea',
#  'Prince61A',
#  'Propa613',
#  'PsychobableJohn',
#  'PuppyResists',
#  'Purpurescens',
#  'RB4444',
#  'RBCUfan',
#  'RGrenzke',
#  'RUSSBOT8675309',
#  'RVSavagePlay',
#  'RaRa75247419',
#  'RantsOutloud',
#  'RealKingMajeed',
#  'RetiredBoomer55',
#  'RickyRayinGA',
#  'RickyTBowles1',
#  'Rmadsen54Barbot',
#  'RmgarrettRose',
#  'Rmitchell424',
#  'RobMT406',
#  'RobertK25802325',
#  'Robin520684511',
#  'RoeFmLI',
#  'Rosa2Arvensis',
#  'Ruby2sday7',
#  'Ruth70154616',
#  'RyanWalis',
#  'SEEANDHEARYOU',
#  'SMR11992',
#  'SO_GOES_LEO',
#  'SPR34231',
#  'SaccoVanzetti',
#  'SandraC42595084',
#  'Sarashara7',
#  'SatNightDP',
#  'SauerElaine',
#  'ScottintheFalls',
#  'Sen_Rob_Boyce',
#  'ShadeBoxer',
#  'ShanJeniah',
#  'ShannyGasm',
#  'Shirley06662518',
#  'ShuttJo',
#  'Sigma_Infinitum',
#  'SilverSoul1964',
#  'Skiridr',
#  'Sloany161',
#  'SportsMaster76',
#  'Spot_martha',
#  'Spunky_1998',
#  'Stacy_Parks56',
#  'StephanOuellet2',
#  'Stephen64332161',
#  'Stephengn',
#  'SteppingGlass',
#  'StewardshipAmer',
#  'SuperSpez',
#  'SweetGeekling',
#  'TDH19761',
#  'TFink86',
#  'TGeis73',
#  'THyunhn',
#  'TIG_Asia',
#  'TONY73922959',
#  'TWITIn4Jesus',
#  'TXIndyGurl',
#  'TammieSueTweets',
#  'Tammy60479677',
#  'TaovicS',
#  'Tatiana18838951',
#  'Tcairns9',
#  'TeresaW25562706',
#  'ThatsMrsRoberts',
#  'The8treGirl',
#  'TheDeepestState',
#  'TheKJFiles',
#  'TheRealJuvenal',
#  'TheRightSide19',
#  'The_Moccasin_',
#  'The_Ouroboros__',
#  'Tilly70',
#  'TimUpton10',
#  'TorCWoman',
#  'Tracy143DC',
#  'TriciaLyman',
#  'TroyWilder318',
#  'TrumpATeam',
#  'TrumpCat04',
#  'TrumpMDCA',
#  'TrumpspeakT',
#  'TryingToUnder12',
#  'TurnTheTide5',
#  'TuxcedoCat',
#  'Underdo86147756',
#  'UrDSU',
#  'Usa1776G',
#  'VSanax',
#  'Vickyjeter4',
#  'Vindaleo',
#  'Vlabsllc',
#  'WHFakeNews',
#  'WSJ',
#  'WabbitHunter3',
#  'Wayne_Swiss',
#  'Wayward888',
#  'WeDaPeople1776',
#  'WeStand4U_llc',
#  'WeloveScottsdle',
#  'WendyWendy48',
#  'WildAcesArizona',
#  'WokeasfC',
#  'XndrBar',
#  'Xto4',
#  'Yasminakill',
#  'Zana92421082',
#  'ZimmererPaul',
#  'Zoe_Emiko',
#  '_CooterBrown_',
#  '_JeremyR_',
#  '_Pierre_Delecto',
#  '_brocktx',
#  '_kylekhaos',
#  'aaronstonemd',
#  'abytw',
#  'accessoreez',
#  'acrossl',
#  'adlver',
#  'admiralonline',
#  'aeiouy',
#  'ahmedora2001',
#  'alil5he3p',
#  'alliejean12',
#  'altNOAA',
#  'amnonzohar',
#  'amylee62',
#  'angieisstellar',
#  'anmattLDN1551',
#  'anwaramin0777',
#  'aralia_racemosa',
#  'autgrind',
#  'avg_joseph',
#  'awb20774',
#  'awwdorable1',
#  'axedailynews',
#  'badmovieman',
#  'bawl',
#  'beadbop',
#  'beeeaaaannnnn',
#  'bentonlee1',
#  'bfraser747',
#  'billefabian',
#  'billisback2019',
#  'blackbird9z',
#  'bluwtrprncess',
#  'bohannon_james',
#  'bookkeepPLUS',
#  'braavos_mercy',
#  'braxton___2',
#  'bsawtx',
#  'bsmorris52',
#  'budlangtenor',
#  'c19e571e608a418',
#  'canadaincrunch',
#  'car_marj',
#  'carlettej1',
#  'catcatdean',
#  'cavachonmama',
#  'cdotmom',
#  'charanguiadas',
#  'cherio39',
#  'cheslie40670812',
#  'chiccozapote',
#  'chucknevola',
#  'cicero945',
#  'cindrianna',
#  'cintigal51',
#  'clarabelluk',
#  'claudiascompan1',
#  'cmacthebigmac1',
#  'colinski11',
#  'cpv820',
#  'critigal1',
#  'crummuffin',
#  'cumming_karen',
#  'daddy__earl',
#  'dadofccx3',
#  'davidpfinney',
#  'dawnnimmo',
#  'dccsh',
#  'dcstorm50',
#  'demochicken',
#  'democrat_sc',
#  'denoif',
#  'denuribe73',
#  'deviousfranklin',
#  'dfragacruz',
#  'dianesbaker1',
#  'djervin67',
#  'doGfOecioV',
#  'donnacaruso2',
#  'donnasaysso',
#  'dorapantv2020',
#  'dwaynecobb',
#  'dwmays',
#  'ellieofa',
#  'endeavourq',
#  'fhobone',
#  'finnegan_peter',
#  'fishyonekenobi',
#  'fitzcfitz',
#  'font4842',
#  'fulhamatl',
#  'funkengruven',
#  'funkyburck',
#  'gabo_savino',
#  'gance_linda',
#  'gentlemanbibby',
#  'gersteppe6',
#  'giandujakiss',
#  'gisellemarieee_',
#  'givensight',
#  'globalist13903',
#  'gosippersliars',
#  'govt45701',
#  'greenrushdomain',
#  'greenscapular',
#  'gregorytrane46',
#  'guitarcomputer',
#  'hangingoutyall',
#  'hankp691',
#  'hartman_judy67',
#  'henalmo',
#  'hollyjo1225',
#  'horrible_helga',
#  'hpshope',
#  'hugh_mannity',
#  'humanbeinz1968',
#  'ialwyz1der2',
#  'ibsharkbait',
#  'ifeanyispace',
#  'impeach_TheDon',
#  'imuarj',
#  'indyjasa',
#  'inthefullnesso3',
#  'irisohana1',
#  'isaacleeceo1',
#  'islandlulu',
#  'itjustdoesntma2',
#  'its500pm',
#  'j_r_mitch',
#  'j_scott_k',
#  'j_thed',
#  'jackhalpin_art',
#  'jacquiestern1',
#  'jammalama',
#  'janetagleason',
#  'jay_renard',
#  'jayaf1980',
#  'jb4tommy',
#  'jbd10611',
#  'jimmypeebles1',
#  'jjs2224',
#  'jml052979',
#  'jmoore22981000',
#  'jocksjig',
#  'joeythegolfer',
#  'jogsphere',
#  'johnschaves',
#  'joiner_matt',
#  'jord4n313',
#  'jslevitt2',
#  'juandangas13',
#  'judemgreen',
#  'juliaspaulding2',
#  'julissa111',
#  'jus_bellum',
#  'k1llurboss',
#  'kaboobola',
#  'khalilsh62',
#  'kimcook67',
#  'kirto_martin',
#  'koletrain2',
#  'kreimes_lisa',
#  'kronstein99',
#  'kyleknight22',
#  'ladysharona',
#  'lafon_alberto',
#  'larklittlefoot',
#  'larrymasonbiz',
#  'larrysmothers12',
#  'lasramisteriosa',
#  'leahlaw23536852',
#  'lebii3271',
#  'lee2skyV',
#  'letitbe1023',
#  'life0fpain',
#  'lilrosebush1',
#  'lisa201349',
#  'lisa89002',
#  'liz5359',
#  'lmboren',
#  'lme644',
#  'loonace666',
#  'loranger_steve',
#  'lucerorose52',
#  'luvmesweeter',
#  'lydiafhall',
#  'lyndiejoy2020',
#  'mabh1832',
#  'mad4sci',
#  'mariogrechi1',
#  'maxtrail1',
#  'mferrell6741',
#  'mgcanmore',
#  'michaelsalinger',
#  'milktea0008',
#  'missliberties',
#  'mitchell20_art',
#  'mojakaczka',
#  'monica4Thomas',
#  'monty_teaches',
#  'msbehling',
#  'mundanemajority',
#  'mwashington4539',
#  'mwc71081',
#  'myst84',
#  'nancy_gtl',
#  'navid66096422',
#  'navyChiefalways',
#  'navywife617',
#  'ndchambers',
#  'noahjacobmama',
#  'notapartyparrot',
#  'off2cdwzrd',
#  'ohlaboday',
#  'olegrdnr',
#  'openpodbaydoor_',
#  'ord3001',
#  'pamelafwood',
#  'pamsedge',
#  'paphotog',
#  'patricklee6669',
#  'pattypaul48',
#  'pax_praeger',
#  'peachyking501',
#  'penny_pesh',
#  'petercr25440273',
#  'pguild1225',
#  'phillipfender5',
#  'phoneladyctt',
#  'pinkliontrash',
#  'pizzahunt42',
#  'plantbasedlove1',
#  'pmdussault',
#  'premil_willy',
#  'price1000000',
#  'prks74634853',
#  'pugo4us',
#  'punshinga',
#  'puppetmaster0x0',
#  'putneyswope7',
#  'racovart1962',
#  'racric1',
#  'ragahee1',
#  'raulisodo',
#  'rbaelite25',
#  'rcruz961',
#  'realoldschool1',
#  'realstuart45',
#  'reedkell9',
#  'rene_los',
#  'reneelemaymay',
#  'renewableworks',
#  'richardireland',
#  'richw2001',
#  'rickgioia',
#  'rmanzo251',
#  'robertwhitelfc',
#  'robsmom3',
#  'rogerfreeman191',
#  'rosea_tony',
#  'roseanddave',
#  'rowen316',
#  'roydert8',
#  'royparrish',
#  'rthanado',
#  's_kupp',
#  'samjohn09135430',
#  'samtosane',
#  'schmidtk21',
#  'scottbushkin',
#  'screen_edits',
#  'seanpmcg1',
#  'seanthegritty',
#  'seeisb',
#  'setiris',
#  'sgeorge52',
#  'shadow20367135',
#  'shefshakespeare',
#  'sherlock31770',
#  'sherwoodp67',
#  'shirley42842516',
#  'siwan33821583',
#  'slartibartphast',
#  'smacdad75',
#  'smr2red',
#  'spokeumbra',
#  'sstempest1',
#  'stack_kate',
#  'stacy_redvirgo',
#  'staysik',
#  'stefa522',
#  'stepho_11',
#  'stephtrek',
#  'steve68116540',
#  'strawpacifist',
#  'stufalk',
#  'suecroasmun',
#  'susurrriot',
#  'svqjournalist',
#  'tainky131',
#  'tatermater314',
#  'tattoomatthew',
#  'teco22222',
#  'tedmallory',
#  'teresamhc',
#  'tewblessone',
#  'thEAdgate',
#  'theLusciousLew',
#  'thepreppyargyle',
#  'thunderchester',
#  'tide_by_90',
#  'tip5063',
#  'tononotomokun',
#  'tonpechs',
#  'topsecretk9',
#  'tracyjenea',
#  'trollingclaire',
#  'trump2trumpIRL',
#  'tsmith724',
#  'v_baltimo',
#  'vacationlvr',
#  'viphires',
#  'vipscafe25',
#  'wall737',
#  'westworld73',
#  'whitenoisyish',
#  'whyterose713',
#  'wist_andy',
#  'woodworker110',
#  'wwshopgirl',
#  'xerdolphin',
#  'yankeesway',
#  'yeatesgreats',
#  'zipillinois'}

# %%
from bs4 import BeautifulSoup
import re
import requests
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent = "gqeeqheh&&email=sbsteinb@andrew.cmu.edu")
from geopy.exc import GeocoderTimedOut
URL_INIT = 'https://twitter.com/'

list_of_users = set(df.screen_name)
#From all scraped tweets, get a set of unique usernames and put them in this list.


#The located userlocations are appended to this list
list_of_found_userlocations = []

#The not located userlocations are appended to this list.
#Maybe they contain some typo or something else like that.
list_of_nonfound_userlocations = []

def parse_url(tweet_user):
    url = URL_INIT+ tweet_user.strip('@')
    return url

for user in list_of_users:
    #print(user)
    try:
        #print("Aa")
        url = parse_url(user)
        #print("GG", url)
        response = requests.get(url)
    except:
        continue
    html = response.content
    soup = BeautifulSoup(html, features="lxml")
    location = soup.find('span','ProfileHeaderCard-locationText').text.strip('\n').strip()
    if location:
        if ',' in location:
            splitted_location = location.split(',')
        else:
            splitted_location = re.split('|;|-|/|°|#', location)
        try:
            if splitted_location:
                located_location = geolocator.geocode(splitted_location[0], timeout=100)
            else:
                located_location = geolocator.geocode(location, timeout=100)
            if located_location:
                user_plus_location = (user, located_location)
                list_of_found_userlocations.append(user_plus_location)
            else:
                user_plus_incorrect_location = (user, location)
                list_of_nonfound_userlocations.append(user_plus_incorrect_location)
        except GeocoderTimedOut as e:
            print("Error: geocode failed on input %s with message %s"%(location, e))

print(list_of_found_userlocations)
print(list_of_nonfound_userlocations)
# Out:
# /Users/scott/anaconda3/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# [('SO_GOES_LEO', Location(California, Baytown, Harris County, Texas, United States, (29.7181118, -94.9979061, 0.0))), ('fulhamatl', Location(Atlanta, Fulton County, Georgia, United States, (33.7490987, -84.3901849, 0.0))), ('thepreppyargyle', Location(South Bend, Saint Joseph County, Indiana, United States of America, (41.6833813, -86.2500066, 0.0))), ('Canadians4RG', Location(Edmonton, Alberta, Canada, (53.535411, -113.507996, 0.0))), ('joiner_matt', Location(Jackson, Hinds County, Mississippi, 39269, United States, (32.2990384, -90.1847691, 0.0))), ('renewableworks', Location(Singapore, Central, Singapore, (1.340863, 103.830391822121, 0.0))), ('lilrosebush1', Location(Hell, Stjørdal, Trøndelag, 7502, Norge, (63.445531, 10.9032872, 0.0))), ('PEltzholtz', Location(New Jersey, United States of America, (40.0757384, -74.4041622, 0.0))), ('Yasminakill', Location(Virginia, United States of America, (37.1232245, -78.4927721, 0.0))), ('AJDarkstar', Location(England, United Kingdom, (52.7954791, -0.540240286617432, 0.0))), ('Blackout20', Location(Colombia, (2.8894434, -73.783892, 0.0))), ('kaboobola', Location(Forever 21, Mall Ring Road, Antelope Valley Mall, Palmdale, Los Angeles County, California, United States of America, (34.6052975, -118.1538315, 0.0))), ('westworld73', Location(United Kingdom, (54.7023545, -3.2765753, 0.0))), ('mwashington4539', Location(Washington, District of Columbia, 20500, United States of America, (38.8948932, -77.0365529, 0.0))), ('ManeBlonde', Location(United States, (39.7837304, -100.4458825, 0.0))), ('tewblessone', Location(United States, (39.7837304, -100.4458825, 0.0))), ('CplFoxCo2_2', Location(Rough As Your Head, Smooth As Glass, Abermain, Tomalpin, Cessnock City Council, New South Wales, 2326, Australia, (-32.8423722, 151.4478053, 0.0))), ('shirley42842516', Location(United States, (39.7837304, -100.4458825, 0.0))), ('ShanJeniah', Location(Stillwater, Payne County, Oklahoma, United States of America, (36.1156306, -97.0585717, 0.0))), ('ChristineOrland', Location(South Carolina, United States of America, (33.6874388, -80.4363743, 0.0))), ('Doomz__Dayz', Location(Metro, Carrera 72D, Surbana, Bosa, Bogotá, Distrito Capital, 111921, Colombia, (4.59739975, -74.1665414519456, 0.0))), ('dccsh', Location(Washington, District of Columbia, 20500, United States of America, (38.8948932, -77.0365529, 0.0))), ('shadow20367135', Location(United States, (39.7837304, -100.4458825, 0.0))), ('colinski11', Location(Philadelphia, Philadelphia County, Pennsylvania, United States of America, (39.9527237, -75.1635262, 0.0))), ('SweetGeekling', Location(Boulder, Boulder County, Colorado, United States, (40.0149856, -105.2705456, 0.0))), ('41MARGIE41', Location(California, United States of America, (36.7014631, -118.7559974, 0.0))), ('KellenSeason', Location(Hell, Stjørdal, Trøndelag, 7502, Norge, (63.445531, 10.9032872, 0.0))), ('Rosa2Arvensis', Location(Rialto, 38, Jana Henryka Dąbrowskiego, Jeżyce, Poznań, województwo wielkopolskie, 60-842, Polska, (52.4115907, 16.9065918, 0.0))), ('itjustdoesntma2', Location(Virginia, United States of America, (37.1232245, -78.4927721, 0.0))), ('AJWoodson', Location(Springfield, Sangamon County, Illinois, United States of America, (39.7990175, -89.6439575, 0.0))), ('Deplorable36', Location(United States, (39.7837304, -100.4458825, 0.0))), ('RickyRayinGA', Location(What’s Up SWFL, 8359, Beacon Boulevard, Fort Myers Villas, Lee County, Florida, 33907, United States, (26.571249, -81.8683533, 0.0))), ('Usa1776G', Location(Savannah, Chatham County, Georgia, United States, (32.0809263, -81.0911768, 0.0))), ('DeborahSotti', Location(Adel, Dallas County, Iowa, United States of America, (41.6175278, -94.0183875, 0.0))), ('Elle4Trump', Location(South Florida, Columbus, Cherokee County, Kansas, 66725, United States, (37.1677128, -94.8464256, 0.0))), ('dorapantv2020', Location(Oz, McCreary County, Kentucky, United States, (36.7064656, -84.5674396, 0.0))), ('TIG_Asia', Location(41, Reparto Rosa L ...
# [('The8treGirl', 'Not at home\xa0🇨🇦 but happy here'), ('Eansanead', 'EU from Éire\xa0🇮🇪 to \xa0🇪🇪Eesti.'), ('ChuckUmeboshi', 'In the Earth not of it'), ('puppetmaster0x0', 'Somewhere in space and time'), ('BDWB3', 'The Big Easy and every rural place in between.'), ('AngDonlon', 'NotGLOBAL https://files.catbox'), ('HRCpersists', 'Northwest #ResistInsistPersist'), ('globalist13903', 'Living on the Globe'), ('samjohn09135430', 'white house/ur childhood'), ('Dukepatriot50', 'http://www.bathandbodyworks.co'), ('Jopatmc1967', 'HTown'), ('Phyllis_Sudds', 'Far from Trump'), ('tainky131', 'NO DMS PLEASE'), ('spokeumbra', 'NKP RTAFB'), ('JosephChez', 'PoliticOpinion ProtectedSpeech'), ('indyjasa', 'Flyover nation'), ('theLusciousLew', 'Earth Prime\xa0🌈\xa0🏳️\u200d🌈\xa0💗\xa0🌟\xa0💙\xa0🌏\xa0💫\xa0❤'), ('RUSSBOT8675309', 'Kekistan'), ('Pecker_Grabber', '🌎'), ('KatiePhang', 'MIA\xa0🛫NYC\xa0🛬MIA'), ('juandangas13', 'I admit it, I am from Calif'), ('tracyjenea', 'where I choose\xa0✈️'), ('ohlaboday', 'The 972 • The 4th City • GP'), ('PKekbar', 'Pepeshire, Kekistan'), ('ILIASIYUN', 'www.centroculturalislamico.co'), ('BassistOld', "I block MAGAt's"), ('TimUpton10', 'Podunk With A Beach, NC'), ('CaseyC89IPA', 'Boyd, IL'), ('MrRichardPaul', 'Ambassador to Greenland'), ('HelloShunshine1', 'Somewhere out there'), ('ShadeBoxer', 'Chlorophylladelphia'), ('LizFoxSays', 'Refugee from California'), ('doGfOecioV', 'Make Florida Republican Again'), ('LiberalDeadHead', 'A distressed America'), ('GretaMiddendor1', 'Trumpland, USA'), ('CapRogers2020', 'Avengers Mansion NYC'), ('stacy_redvirgo', 'Deep\xa0🐊Louisiana Swamp\xa0⚜️'), ('realoldschool1', 'In front of computer screen'), ('badmovieman', 'The Outta London Wasteland'), ('aeiouy', 'iPhone SHHHH!'), ('AmandaD85547309', 'Your girlfriends mind'), ('KidApologize', 'Back Wash of Fenerio'), ('OpiesDaughter', 'Dayton Strong'), ('Jess_deladono', 'Christ. Who knows.'), ('NotMyFlyMonkeys', 'In the middle of America'), ('MichaelMiguelCE', '48 Civil Engineer Philippines'), ('Matt60944173', 'Usa can uk'), ('ImChaunce', 'Central AL\xa0✈NW IN raised \xa0🇺🇸'), ('_CooterBrown_', '🇨🇱'), ('crummuffin', 'Thompson Ohio (Cleveland area)'), ('beadbop', 'Windmolen Centraal'), ('Bryan_Baruch1', 'MIAMI/Boca Raton/Los Angeles'), ('Skiridr', 'BX  QB  LI, NY \xa0☝'), ('dawnnimmo', 'Followed by General Flynn'), ('pax_praeger', 'Wherever I’m Most Needed, USA')]
